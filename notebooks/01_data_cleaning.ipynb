# %% [markdown]
# ### Giai đoạn 1: Làm sạch dữ liệu (Data Cleaning)

# %% [markdown]
# #### Do sử dụng `generate_data.py` để tạo dữ liệu giả lập (synthetic data) có cấu trúc chuẩn sẵn, nên bước làm sạch dữ liệu thủ công không còn cần thiết. Ở các dự án thực tế với dữ liệu thu thập (crawl) từ web, thư mục này sẽ chứa code xử lý missing values, chuẩn hóa tên trường, xóa các dòng lỗi, v...v...
