# %% [markdown]
# ### Giai đoạn 2: Tạo đặc trưng (Feature Engineering)

# %% [markdown]
# #### Khám phá dữ liệu
# Trong file này, ta sẽ xem trước dữ liệu đã được xử lý bằng script để hiểu các the features đưa vào model Machine Learning.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Xem dữ liệu đặc trưng các trường
# Đây là dữ liệu điểm chuẩn 3 năm của các trường và các features đã được tính toán (như xu hướng, độ biến động).

# %%
df = pd.read_csv('../data/processed/feature_engineered.csv')
df.head()

# %% [markdown]
# #### Xem dữ liệu Training
# - Đây là dữ liệu mô phỏng 4000 thí sinh với các mức điểm thi khác nhau và `ket_qua` đỗ/trượt, dùng để train model.

# %%
df_train = pd.read_csv('../data/processed/training_data.csv')
df_train.head()
